# %%
import pickle
import sympy as sp

print("Loading results from pickle files...")

with open("moment1.pkl", "rb") as f:
    res1 = pickle.load(f)
    E_x = res1["E_x"]
    t1 = res1["time_seconds"]
    print(f"Loaded E_x: {E_x}")
    print(f"Time taken (Moment 1): {t1:.4f}s")

with open("moment2.pkl", "rb") as f:
    res2 = pickle.load(f)
    sum_weighted_score = res2["sum_weighted_score"]
    t2 = res2["time_seconds"]
    print(f"Loaded Sum Weighted Score: {sum_weighted_score}")
    print(f"Time taken (Moment 2): {t2:.4f}s")
# Out:
# Loading results from pickle files...
# Loaded E_x: 141909.3299550069189074010816111740819247526879963533562108532930546123896547489738546946426076501812
# Time taken (Moment 1): 0.1806s
# Loaded Sum Weighted Score: 20138200387.27553064062356480949398731946917601950964320025875032602295725449590073222759099816446411
# Time taken (Moment 2): 1.5981s

# %%
# Calculate Variance and Std Dev
Var_x = sum_weighted_score + E_x - E_x**2
Std_Dev = sp.re(Var_x**0.5)

print("\n--- Final Results ---")
print(f"Expectation (E_x): {E_x}")
print(f"Variance (Var_x):  {Var_x}")
print(f"Std Dev:           {Std_Dev}")
print(f"Total Calculation Time: {t1 + t2:.4f}s")
# Out:
# --- Final Results ---
# Expectation (E_x): 141909.3299550069189074010816111740819247526879963533562108532930546123896547489738546946426076501812
# Variance (Var_x):  84368.32646163049085579893634725520134429317616953988852869425105032494704481361230931683801137749095
# Std Dev:           290.4622634037517976866816296408668206306452772295310088020052094422443421216487908289287875253080963
# Total Calculation Time: 1.7787s
